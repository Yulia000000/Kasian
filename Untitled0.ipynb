# %% [markdown]
# <a href="https://colab.research.google.com/github/Yulia000000/Kasian/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'x':[1,3,2],'y':[2,4,1]})
df
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df1=pd.DataFrame({'x':[1,3,2],'y':[2,4,1]})
df2=pd.DataFrame({'x':[3,2,1],'y':[0,2,2]})
print (df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df[df1>1]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  NaN NaN
# 2  1.0 NaN

# %%
df2[(df2<1)|(df2>2)]
# Out:
#      x    y
# 0  3.0  0.0
# 1  NaN  NaN
# 2  NaN  NaN

# %%
data={'Имя':['Анна','Борис', None, 'Джон'],'Возраст':[25,30,28,None]}
df=pd.DataFrame(data)
df
# Out:
#      Имя  Возраст
# 0   Анна     25.0
# 1  Борис     30.0
# 2   None     28.0
# 3   Джон      NaN

# %%
x=df.isnull()
df.isnull().loc[x["Имя"]==True]
# Out:
#     Имя  Возраст
# 2  True    False
